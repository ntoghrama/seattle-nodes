# %% [markdown]
# #### Processing strategies for urban seismic noise in Seattle

# %%
# module imports
import sys
import matplotlib.pyplot as plt

# %%
# add a function to get a stack for a station1.component1 -station2.component2 pair from NoisePy output files
def get_stack_trace_from_noisepy(output_directory_of_stacks, sta1, cha1, sta2, cha2):
    # something
    tr = []
    
    # add sampling rate. tr could be an obspy trace, or just an array with a separate variable for sampling rate
    return(tr)

# %%
# add a function to get a stack for a station1.component1 -station2.component2 pair from Ruido output files
def get_stack_trace_from_ruido(output_directory_of_stacks, sta1, cha1, sta2, cha2):
    # something
    tr = []
    
    # add sampling rate. tr could be an obspy trace, or just an array with a separate variable for sampling rate
    return(tr)

# %%
# user input

# The dictionaries could specify the different processing runs by a key.
# This would also allow to identify noisepy outputs with further steps in ruido (using same key)

# in each of the noisepy setups should be a directory with the noisepy main script prepared 
# to run by the user, with the processing specified as they wish
noisepy_setups = {"whiten_rma": "/path/to/directory1",
                   "nowhiten": "/path/to/directory2",
                   "nowhiten_and_postwhiten_in_ruido": "/path/to/directory2",
                   "whiten_and_onebit": "/path/to/directory3"}

# for some of the noisepy output, we would then use further steps in ruido, like clustering and 
# cluster-specific stacking
ruido_setups = {"nowhiten": "/path/to/inputfile1",
                "nowhiten_and_postwhiten_in_ruido": "/path/to/inputfile2"}

# using these directories, we could later also access the stacked output (both ruido and noisepy)

# %%
# for each key in the dictionary of noisepy: Run noisepy!
# for (k, v) in noisepy....:
#     os.system(run the command to invoke this noisepy setup...)

# %%
# for the dictionary entries of ruido: Run ruido!
# for (k, inputfile_x) in ruido_setups...:
#    os.system("mpirun -np <cores> python /path/to/ruido_main.py /path/to/inputfile_x")

# %%
# then, get the stack traces and compare.

# plot different processing outcomes for a small number of station pairs
